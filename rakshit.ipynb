# %%
import pandas as pd

# %%
import glob

# %%
images = [i for i in os.listdir('datasets/aquarium2007/JPEGImages/') if 'IMG' in i]
img_paths = [os.path.join('datasets/aquarium2007/JPEGImages/', i) for i in images][:6]
def load_images_from_folder(img_paths):
    images = []
    for filename in img_paths:
        # img = cv2.imread(filename)
        image = mpimg.imread(filename)
        # <something gets done here>
        plt.figure()
        plt.imshow(image)
    #     if img is not None:
    #         images.append(img)
    # return images

# %%
v_slice = load_images_from_folder(img_paths)
# plt.figure()

# #subplot(r,c) provide the no. of rows and columns
# f, axarr = plt.subplots(4,1) 

# # use the created array to output your multiple images. In this case I have stacked 4 images vertically
# axarr[0].imshow(v_slice[0])
# axarr[1].imshow(v_slice[1])
# axarr[2].imshow(v_slice[2])
# axarr[3].imshow(v_slice[3])

# %%
import os
import cv2
import numpy as np
import random
import math

import matplotlib
from matplotlib.pyplot import imshow
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# dir_path = 'img'
images = [i for i in os.listdir('datasets/aquarium2007/JPEGImages/') if 'IMG' in i]
img_paths = [os.path.join('datasets/aquarium2007/JPEGImages/', i) for i in images][:6]
# img_paths.sort()
img_all = np.array([cv2.cvtColor(cv2.imread(p), cv2.COLOR_BGR2RGB) for p in img_paths])


def display_helper(images, cmap=None):
    fig, ax = plt.subplots(nrows=2, ncols=3, figsize=(15,6))
    # fig, ax = plt.subplots(nrows=20, ncols=2, figsize=(15,6))
    for a in ax[0]:
        a.imshow(images, interpolation='none')

display_helper(img_all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-2c27b1575553> in <module>
#      24         a.imshow(images, interpolation='none')
#      25
# ---> 26 display_helper(img_all)
#
# <ipython-input-23-2c27b1575553> in display_helper(images, cmap)
#      22     # fig, ax = plt.subplots(nrows=20, ncols=2, figsize=(15,6))
#      23     for a in ax[0]:
# ---> 24         a.imshow(images, interpolation='none')
#      25
#      26 display_helper(img_all)
#
# C:\Python39\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1350     def inner(ax, *args, data=None, **kwargs):
#    1351         if data is None:
# -> 1352             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1353
#    1354         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
# !pip install matplotlib
# Out:
# ^C

# %%
glob.glob('datasets/aquarium2007/JPEGImages/IMG*')
# Out:
# JPEGImages\\IMG_3176_jpeg_jpg.rf.d2ccf3978d7846c94fcb5d7700ea50dc.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3177_jpeg_jpg.rf.21ff231136bee6d8d2d88475c2ca47ce.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3178_jpeg_jpg.rf.ac2bd83268ddfaa7d82bb77743bccc82.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3179_jpeg_jpg.rf.23e30f6b494cb6c2ff3ac42c450b0ee2.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3180_jpeg_jpg.rf.ab8c84e6f82bfb062f068c5d741dd6d7.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3181_jpeg_jpg.rf.c52b54494d4236e54b900fe60bd6565b.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3182_jpeg_jpg.rf.3e85376545651810d891af33d25e6bcf.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3183_jpeg_jpg.rf.342a406c147ecc3678bc2669b9d2f2b6.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3184_jpeg_jpg.rf.67485e67375b442b6ac3462554ccc816.jpg',
#  'datasets/aquarium2007/JPEGImages\\IMG_3185_jpeg_jpg.rf.82a017bce2929b7cb1e9104a0a22ffe7.jpg',
# ...

# %%
[i for i in os.listdir('datasets/aquarium2007/JPEGImages/') if 'IMG' in i]
# Out:
# IMG_2594_jpeg_jpg.rf.40698b5028ec7d9443d65a38b58bec42.jpg',
#  'IMG_2595_jpeg_jpg.rf.1c8b482b1ad0ca6648e61b694ed4ee83.jpg',
#  'IMG_2596_jpeg_jpg.rf.55aa05115a4c3f538df4e9941af1396d.jpg',
#  'IMG_2597_jpeg_jpg.rf.0f07eb126fe35d31acdbec7adb23ed50.jpg',
#  'IMG_2598_jpeg_jpg.rf.5650ef75065f27a08cb74975840016a5.jpg',
#  'IMG_2599_jpeg_jpg.rf.88b1e110db566b217338891ffdb87ac3.jpg',
#  'IMG_2600_jpeg_jpg.rf.a21b557f64e4a16ae3678de9aef1923a.jpg',
#  'IMG_2601_jpeg_jpg.rf.6db2e040b561c055befb49ca877632b3.jpg',
#  'IMG_2602_jpeg_jpg.rf.9614bcb0af2cc0b4530c8859ba06e026.jpg',
#  'IMG_2603_jpeg_jpg.rf.6d8a5a94a16c04784eae01d5d07f8cbe.jpg',
#  'IMG_2604_jpeg_jpg.rf.993c6667a03fd897ea35c645df9ee93d.jpg',
#  'IMG_2605_jpeg_jpg.rf.2d62821e1b21d2a61a98252c59a4042e.jpg',
#  'IMG_2606_jpeg_jpg.rf.27e5a373d43d2535a923e1089bf60051.jpg',
#  'IMG_2607_jpeg_jpg.rf.f969243b3db0c2242280e1aad0f4a0b8.jpg',
#  'IMG_2608_jpeg_jpg.rf.9ba9cc2485112df87a73dee448aad2bc.jpg',
# ...
